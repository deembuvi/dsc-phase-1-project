# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: DIANA MBUVI
# * Student pace: PART TIME

# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Importing the data

# %% [markdown]
# # UNDERSTANDING THE DATA

# %%
df=pd.read_csv('C:/Users/Lenovo/Desktop/Phase_one_project/dsc-phase-1-project/zippedData/tmdb.movies.csv', index_col=0)
df

#reading the data from a csv file
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 9 columns]

# %%
df1=pd.read_csv('C:/Users/Lenovo/Desktop/Phase_one_project/dsc-phase-1-project/zippedData/tn.movie_budgets.csv', index_col=0)
df1

#reading the data from a csv file
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..           ...                                          ...
# 78  Dec 31, 2018                                       Red 11
# 79   Apr 2, 1999                                    Following
# 80  Jul 13, 2005                Return to the Land of Wonders
# 81  Sep 29, 2015                         A Plague So Pleasant
# 82   Aug 5, 2005                            My Date With Drew
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747
# ..               ...            ...             ...
# 78            $7,000             $0              $0
# 79            $6,000        $48,482        $240,495
# 80            $5,000         $1,338          $1,338
# 81            $1,400             $0              $0
# 82            $1,100       $181,041        $181,041
#
# [5782 rows x 5 columns]

# %%
df.columns #getting the columns titles from the data
# Out:
# Index(['genre_ids', 'id', 'original_language', 'original_title', 'popularity',
#        'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df1.columns #getting the columns from the second data set
# Out:
# Index(['release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %%
# Convert 'release_date' to datetime type
df['release_date'] = pd.to_datetime(df['release_date'])
df1['release_date'] = pd.to_datetime(df1['release_date'])

# Merge the dataframes based on 'release_date' and 'original_title'
df2= pd.merge(df, df1, left_on=['release_date', 'original_title'], right_on=['release_date', 'movie'], how='inner')

# Display the merged dataframe
df2
# Out:
#                 genre_ids      id original_language  \
# 0     [14, 12, 16, 10751]   10191                en
# 1           [12, 28, 878]   10138                en
# 2         [16, 35, 10751]     862                en
# 3         [16, 35, 10751]     862                en
# 4           [28, 878, 12]   27205                en
# ...                   ...     ...               ...
# 1396         [53, 18, 27]  510284                en
# 1397          [18, 10752]  514407                en
# 1398         [18, 28, 80]  547590                en
# 1399     [18, 35, 28, 80]  506971                ur
# 1400         [28, 12, 16]  332718                en
#
#                   original_title  popularity release_date  \
# 0       How to Train Your Dragon      28.734   2010-03-26
# 1                     Iron Man 2      28.515   2010-05-07
# 2                      Toy Story      28.005   1995-11-22
# 3                      Toy Story      28.005   1995-11-22
# 4                      Inception      27.920   2010-07-16
# ...                          ...         ...          ...
# 1396                       Braid       5.972   2019-02-01
# 1397                 Indivisible       5.599   2018-10-26
# 1398                  El Chicano       5.274   2019-05-03
# 1399            Teefa in Trouble       4.486   2018-07-20
# 1400  Bilal: A New Breed of Hero       2.707   2018-02-02
#
#                            title  vote_average  vote_count  \
# 0       How to Train Your Dragon           7.7        7610
# 1                     Iron Man 2           6.8       12368
# 2                      Toy Story           7.9       10174
# 3                      Toy Story           7.9       10174
# 4                      Inception           8.3       22186
# ...                          ...           ...         ...
# 1396                       Braid           6.4          18
# 1397                 Indivisible           5.4          13
# 1398                  El Chicano           9.0           1
# 1399            Teefa in Trouble           7.6          11
# 1400  Bilal: A New Breed of Hero           6.8          54
#
#                            movie production_budget domestic_gross  \
# 0       How to Train Your Dragon      $165,000,000   $217,581,232
# 1                     Iron Man 2      $170,000,000   $312,433,331
# 2                      Toy Story       $30,000,000   $191,796,233
# 3                      Toy Story       $30,000,000   $191,796,233
# 4                      Inception      $160,000,000   $292,576,195
# ...                          ...               ...            ...
# 1396                       Braid        $1,660,000             $0
# 1397                 Indivisible        $2,700,000     $3,511,417
# 1398                  El Chicano        $8,000,000       $700,261
# 1399            Teefa in Trouble        $1,500,000             $0
# 1400  Bilal: A New Breed of Hero       $30,000,000       $490,973
#
#      worldwide_gross
# 0       $494,870,992
# 1       $621,156,389
# 2       $364,545,516
# 3       $364,545,516
# 4       $835,524,642
# ...              ...
# 1396         $80,745
# 1397      $3,588,305
# 1398        $700,261
# 1399         $98,806
# 1400        $648,599
#
# [1401 rows x 13 columns]

# %%
df2.head() #getting the first 5 rows of the data
# Out:
#              genre_ids     id original_language            original_title  \
# 0  [14, 12, 16, 10751]  10191                en  How to Train Your Dragon
# 1        [12, 28, 878]  10138                en                Iron Man 2
# 2      [16, 35, 10751]    862                en                 Toy Story
# 3      [16, 35, 10751]    862                en                 Toy Story
# 4        [28, 878, 12]  27205                en                 Inception
#
#    popularity release_date                     title  vote_average  \
# 0      28.734   2010-03-26  How to Train Your Dragon           7.7
# 1      28.515   2010-05-07                Iron Man 2           6.8
# 2      28.005   1995-11-22                 Toy Story           7.9
# 3      28.005   1995-11-22                 Toy Story           7.9
# 4      27.920   2010-07-16                 Inception           8.3
#
#    vote_count                     movie production_budget domestic_gross  \
# 0        7610  How to Train Your Dragon      $165,000,000   $217,581,232
# 1       12368                Iron Man 2      $170,000,000   $312,433,331
# 2       10174                 Toy Story       $30,000,000   $191,796,233
# 3       10174                 Toy Story       $30,000,000   $191,796,233
# 4       22186                 Inception      $160,000,000   $292,576,195
#
#   worldwide_gross
# 0    $494,870,992
# 1    $621,156,389
# 2    $364,545,516
# 3    $364,545,516
# 4    $835,524,642

# %%
df2.info() #gives information about the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1401 entries, 0 to 1400
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          1401 non-null   object
#  1   id                 1401 non-null   int64
#  2   original_language  1401 non-null   object
#  3   original_title     1401 non-null   object
#  4   popularity         1401 non-null   float64
#  5   release_date       1401 non-null   datetime64[ns]
#  6   title              1401 non-null   object
#  7   vote_average       1401 non-null   float64
#  8   vote_count         1401 non-null   int64
#  9   movie              1401 non-null   object
#  10  production_budget  1401 non-null   object
#  11  domestic_gross     1401 non-null   object
#  12  worldwide_gross    1401 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 153.2+ KB

# %%
df2.dtypes #getting the type of data
# Out:
# genre_ids                    object
# id                            int64
# original_language            object
# original_title               object
# popularity                  float64
# release_date         datetime64[ns]
# title                        object
# vote_average                float64
# vote_count                    int64
# movie                        object
# production_budget            object
# domestic_gross               object
# worldwide_gross              object
# dtype: object

# %%
df2.describe() #describes the data
# Out:
#                   id   popularity  vote_average    vote_count
# count    1401.000000  1401.000000   1401.000000   1401.000000
# mean   202685.153462    13.346337      6.346824   2243.757316
# std    138350.904263     8.051220      0.865988   2993.835538
# min        95.000000     0.600000      3.000000      1.000000
# 25%     68728.000000     8.459000      5.800000    373.000000
# 50%    205584.000000    11.546000      6.400000   1097.000000
# 75%    323676.000000    16.302000      6.900000   2817.000000
# max    547590.000000    80.773000      9.000000  22186.000000

# %%
df2.isna().sum() #gives the number of empty values per column
# Out:
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %% [markdown]
# There were no missing values in the columns.

# %%
df2.isna().sum().sum() #gives number of empty values in entires data
# Out:
# 0

# %% [markdown]
# There were no missing values.

# %%
duplicate_rows= df2[df2.duplicated()] #checking for duplicated rows
duplicate_rows
# Out:
#             genre_ids      id original_language                original_title  \
# 3     [16, 35, 10751]     862                en                     Toy Story
# 86        [18, 10749]   46705                en                Blue Valentine
# 112          [35, 18]   46829                en              Barney's Version
# 131              [18]   59728                en               The 5th Quarter
# 145   [18, 36, 10752]     387                de                      Das Boot
# ...               ...     ...               ...                           ...
# 1248    [35, 18, 878]  301337                en                    Downsizing
# 1257         [18, 12]  407890                en                  Lean on Pete
# 1263             [18]  300687                en  Same Kind of Different as Me
# 1266         [28, 35]  398177                en          Just Getting Started
# 1272             [18]  392982                en                      Marshall
#
#       popularity release_date                         title  vote_average  \
# 3         28.005   1995-11-22                     Toy Story           7.9
# 86         8.994   2010-12-29                Blue Valentine           6.9
# 112        7.357   2011-01-14              Barney's Version           7.2
# 131        2.142   2011-03-25               The 5th Quarter           4.7
# 145       16.554   1982-02-10                      Das Boot           8.1
# ...          ...          ...                           ...           ...
# 1248      10.682   2017-12-22                    Downsizing           5.1
# 1257       9.307   2018-04-06                  Lean on Pete           6.9
# 1263       8.756   2017-10-20  Same Kind of Different as Me           6.8
# 1266       8.459   2017-12-08          Just Getting Started           4.9
# 1272       7.879   2017-10-13                      Marshall           7.3
#
#       vote_count                         movie production_budget  \
# 3          10174                     Toy Story       $30,000,000
# 86          1677                Blue Valentine        $1,000,000
# 112          210              Barney's Version       $30,000,000
# 131           15               The 5th Quarter        $6,000,000
# 145          981                      Das Boot       $12,000,000
# ...          ...                           ...               ...
# 1248        1887                    Downsizing       $68,000,000
# 1257         133                  Lean on Pete        $8,000,000
# 1263         103  Same Kind of Different as Me        $6,500,000
# 1266          94          Just Getting Started       $22,000,000
# 1272         257                      Marshall       $12,000,000
#
#      domestic_gross worldwide_gross
# 3      $191,796,233    $364,545,516
# 86       $9,737,892     $16,566,240
# 112      $7,502,560      $8,845,575
# 131        $408,159        $408,159
# 145     $11,487,676     $84,970,337
# ...             ...             ...
# 1248    $24,449,754     $54,462,971
# 1257     $1,163,056      $2,455,027
# 1263     $6,423,605      $6,423,605
# 1266     $6,069,605      $6,756,412
# 1272    $10,051,659     $10,116,816
#
# [130 rows x 13 columns]

# %%
df2=df2.drop_duplicates() #displays data after dropping duplicated rows
df2
# Out:
#                 genre_ids      id original_language  \
# 0     [14, 12, 16, 10751]   10191                en
# 1           [12, 28, 878]   10138                en
# 2         [16, 35, 10751]     862                en
# 4           [28, 878, 12]   27205                en
# 5       [28, 12, 14, 878]   19995                en
# ...                   ...     ...               ...
# 1396         [53, 18, 27]  510284                en
# 1397          [18, 10752]  514407                en
# 1398         [18, 28, 80]  547590                en
# 1399     [18, 35, 28, 80]  506971                ur
# 1400         [28, 12, 16]  332718                en
#
#                   original_title  popularity release_date  \
# 0       How to Train Your Dragon      28.734   2010-03-26
# 1                     Iron Man 2      28.515   2010-05-07
# 2                      Toy Story      28.005   1995-11-22
# 4                      Inception      27.920   2010-07-16
# 5                         Avatar      26.526   2009-12-18
# ...                          ...         ...          ...
# 1396                       Braid       5.972   2019-02-01
# 1397                 Indivisible       5.599   2018-10-26
# 1398                  El Chicano       5.274   2019-05-03
# 1399            Teefa in Trouble       4.486   2018-07-20
# 1400  Bilal: A New Breed of Hero       2.707   2018-02-02
#
#                            title  vote_average  vote_count  \
# 0       How to Train Your Dragon           7.7        7610
# 1                     Iron Man 2           6.8       12368
# 2                      Toy Story           7.9       10174
# 4                      Inception           8.3       22186
# 5                         Avatar           7.4       18676
# ...                          ...           ...         ...
# 1396                       Braid           6.4          18
# 1397                 Indivisible           5.4          13
# 1398                  El Chicano           9.0           1
# 1399            Teefa in Trouble           7.6          11
# 1400  Bilal: A New Breed of Hero           6.8          54
#
#                            movie production_budget domestic_gross  \
# 0       How to Train Your Dragon      $165,000,000   $217,581,232
# 1                     Iron Man 2      $170,000,000   $312,433,331
# 2                      Toy Story       $30,000,000   $191,796,233
# 4                      Inception      $160,000,000   $292,576,195
# 5                         Avatar      $425,000,000   $760,507,625
# ...                          ...               ...            ...
# 1396                       Braid        $1,660,000             $0
# 1397                 Indivisible        $2,700,000     $3,511,417
# 1398                  El Chicano        $8,000,000       $700,261
# 1399            Teefa in Trouble        $1,500,000             $0
# 1400  Bilal: A New Breed of Hero       $30,000,000       $490,973
#
#      worldwide_gross
# 0       $494,870,992
# 1       $621,156,389
# 2       $364,545,516
# 4       $835,524,642
# 5     $2,776,345,279
# ...              ...
# 1396         $80,745
# 1397      $3,588,305
# 1398        $700,261
# 1399         $98,806
# 1400        $648,599
#
# [1271 rows x 13 columns]

# %%
vote_count = df2['vote_count'].max() #checking the highest number of votes
vote_count
# Out:
# 22186

# %%
average_vote_count = df2['vote_count'].mean() #getting the mean of the vote count
average_vote_count
# Out:
# 2164.369000786782

# %%
mode_vote_count = df2['vote_count'].mode() #getting the mode of the vote count
mode_vote_count
# Out:
# 0    6
# Name: vote_count, dtype: int64

# %%
median_vote_count = df2['vote_count'].median() #getting the median of the vote count
median_vote_count
# Out:
# 1058.0

# %%
df2 = df2[df2['vote_count'] >= 1058] #dropping the rows with an average vote count less than 1058
df2.reset_index(drop=True, inplace=True)
df2
# Out:
#                 genre_ids      id original_language            original_title  \
# 0     [14, 12, 16, 10751]   10191                en  How to Train Your Dragon
# 1           [12, 28, 878]   10138                en                Iron Man 2
# 2         [16, 35, 10751]     862                en                 Toy Story
# 3           [28, 878, 12]   27205                en                 Inception
# 4       [28, 12, 14, 878]   19995                en                    Avatar
# ..                    ...     ...               ...                       ...
# 631        [9648, 27, 53]  406563                en   Insidious: The Last Key
# 632       [35, 18, 10749]  449176                en               Love, Simon
# 633              [53, 27]  460019                en             Truth or Dare
# 634   [10752, 18, 36, 28]  429351                en                 12 Strong
# 635  [12, 878, 10751, 14]  407451                en         A Wrinkle in Time
#
#      popularity release_date                     title  vote_average  \
# 0        28.734   2010-03-26  How to Train Your Dragon           7.7
# 1        28.515   2010-05-07                Iron Man 2           6.8
# 2        28.005   1995-11-22                 Toy Story           7.9
# 3        27.920   2010-07-16                 Inception           8.3
# 4        26.526   2009-12-18                    Avatar           7.4
# ..          ...          ...                       ...           ...
# 631      16.017   2018-01-05   Insidious: The Last Key           6.1
# 632      15.608   2018-03-16               Love, Simon           8.2
# 633      14.354   2018-04-13             Truth or Dare           6.0
# 634      13.183   2018-01-19                 12 Strong           5.6
# 635      12.529   2018-03-09         A Wrinkle in Time           5.0
#
#      vote_count                     movie production_budget domestic_gross  \
# 0          7610  How to Train Your Dragon      $165,000,000   $217,581,232
# 1         12368                Iron Man 2      $170,000,000   $312,433,331
# 2         10174                 Toy Story       $30,000,000   $191,796,233
# 3         22186                 Inception      $160,000,000   $292,576,195
# 4         18676                    Avatar      $425,000,000   $760,507,625
# ..          ...                       ...               ...            ...
# 631        1306   Insidious: The Last Key       $10,000,000    $67,745,330
# 632        3165               Love, Simon       $10,000,000    $40,826,341
# 633        2005             Truth or Dare        $3,500,000    $41,411,015
# 634        1312                 12 Strong       $35,000,000    $45,819,713
# 635        1073         A Wrinkle in Time      $103,000,000   $100,478,608
#
#     worldwide_gross
# 0      $494,870,992
# 1      $621,156,389
# 2      $364,545,516
# 3      $835,524,642
# 4    $2,776,345,279
# ..              ...
# 631    $167,885,588
# 632     $65,520,633
# 633     $95,127,344
# 634     $71,118,378
# 635    $133,401,882
#
# [636 rows x 13 columns]

# %%
vote_average = df2['vote_average'].max() #the highest vote average
vote_average
# Out:
# 8.4

# %%
df2_sort = df2.sort_values(by=['vote_average'], ascending=True) #sorting to get the least vote_average
df2_sort
# Out:
#                genre_ids      id original_language  \
# 93                  [35]   71880                en
# 420                 [53]  241251                en
# 375        [28, 12, 878]  166424                en
# 233                 [35]   87818                en
# 15   [28, 12, 10751, 14]   10196                en
# ..                   ...     ...               ...
# 590             [18, 35]  490132                en
# 579         [12, 28, 14]  299536                en
# 3          [28, 878, 12]   27205                en
# 270          [18, 10402]  244786                en
# 131             [18, 80]     311                en
#
#                   original_title  popularity release_date  \
# 93                 Jack and Jill      11.277   2011-11-11
# 420            The Boy Next Door       7.062   2015-01-23
# 375               Fantastic Four      16.360   2015-08-07
# 233                     Movie 43      12.813   2013-01-25
# 15            The Last Airbender      16.595   2010-07-01
# ..                           ...         ...          ...
# 590                   Green Book      36.284   2018-11-16
# 579       Avengers: Infinity War      80.773   2018-04-27
# 3                      Inception      27.920   2010-07-16
# 270                     Whiplash      28.784   2014-10-10
# 131  Once Upon a Time in America      17.717   1984-06-01
#
#                            title  vote_average  vote_count  \
# 93                 Jack and Jill           4.1        1124
# 420            The Boy Next Door           4.4        1382
# 375               Fantastic Four           4.4        3837
# 233                     Movie 43           4.4        1332
# 15            The Last Airbender           4.6        2143
# ..                           ...           ...         ...
# 590                   Green Book           8.3        3499
# 579       Avengers: Infinity War           8.3       13948
# 3                      Inception           8.3       22186
# 270                     Whiplash           8.4        7908
# 131  Once Upon a Time in America           8.4        2243
#
#                            movie production_budget domestic_gross  \
# 93                 Jack and Jill       $79,000,000    $74,158,157
# 420            The Boy Next Door        $4,000,000    $36,006,065
# 375               Fantastic Four      $120,000,000    $56,117,548
# 233                     Movie 43       $10,000,000     $8,840,453
# 15            The Last Airbender      $150,000,000   $131,772,187
# ..                           ...               ...            ...
# 590                   Green Book       $23,000,000    $85,080,171
# 579       Avengers: Infinity War      $300,000,000   $678,815,482
# 3                      Inception      $160,000,000   $292,576,195
# 270                     Whiplash        $3,300,000    $13,092,006
# 131  Once Upon a Time in America       $30,000,000     $5,321,508
#
#     worldwide_gross
# 93     $150,519,217
# 420     $53,401,938
# 375    $167,849,187
# 233     $31,164,747
# 15     $319,713,881
# ..              ...
# 590    $322,034,439
# 579  $2,048,134,200
# 3      $835,524,642
# 270     $38,969,037
# 131      $5,575,648
#
# [636 rows x 13 columns]

# %%
df2_sort = df2.sort_values(by=['vote_average'], ascending=False) #sorting values from the highest vote average
df2_sort
# Out:
#                genre_ids      id original_language  \
# 131             [18, 80]     311                en
# 270          [18, 10402]  244786                en
# 579         [12, 28, 14]  299536                en
# 3          [28, 878, 12]   27205                en
# 590             [18, 35]  490132                en
# ..                   ...     ...               ...
# 15   [28, 12, 10751, 14]   10196                en
# 375        [28, 12, 878]  166424                en
# 420                 [53]  241251                en
# 233                 [35]   87818                en
# 93                  [35]   71880                en
#
#                   original_title  popularity release_date  \
# 131  Once Upon a Time in America      17.717   1984-06-01
# 270                     Whiplash      28.784   2014-10-10
# 579       Avengers: Infinity War      80.773   2018-04-27
# 3                      Inception      27.920   2010-07-16
# 590                   Green Book      36.284   2018-11-16
# ..                           ...         ...          ...
# 15            The Last Airbender      16.595   2010-07-01
# 375               Fantastic Four      16.360   2015-08-07
# 420            The Boy Next Door       7.062   2015-01-23
# 233                     Movie 43      12.813   2013-01-25
# 93                 Jack and Jill      11.277   2011-11-11
#
#                            title  vote_average  vote_count  \
# 131  Once Upon a Time in America           8.4        2243
# 270                     Whiplash           8.4        7908
# 579       Avengers: Infinity War           8.3       13948
# 3                      Inception           8.3       22186
# 590                   Green Book           8.3        3499
# ..                           ...           ...         ...
# 15            The Last Airbender           4.6        2143
# 375               Fantastic Four           4.4        3837
# 420            The Boy Next Door           4.4        1382
# 233                     Movie 43           4.4        1332
# 93                 Jack and Jill           4.1        1124
#
#                            movie production_budget domestic_gross  \
# 131  Once Upon a Time in America       $30,000,000     $5,321,508
# 270                     Whiplash        $3,300,000    $13,092,006
# 579       Avengers: Infinity War      $300,000,000   $678,815,482
# 3                      Inception      $160,000,000   $292,576,195
# 590                   Green Book       $23,000,000    $85,080,171
# ..                           ...               ...            ...
# 15            The Last Airbender      $150,000,000   $131,772,187
# 375               Fantastic Four      $120,000,000    $56,117,548
# 420            The Boy Next Door        $4,000,000    $36,006,065
# 233                     Movie 43       $10,000,000     $8,840,453
# 93                 Jack and Jill       $79,000,000    $74,158,157
#
#     worldwide_gross
# 131      $5,575,648
# 270     $38,969,037
# 579  $2,048,134,200
# 3      $835,524,642
# 590    $322,034,439
# ..              ...
# 15     $319,713,881
# 375    $167,849,187
# 420     $53,401,938
# 233     $31,164,747
# 93     $150,519,217
#
# [636 rows x 13 columns]

# %%
# Convert columns to numeric for calculations
df2['worldwide_gross'] = pd.to_numeric(df2['worldwide_gross'].str.replace('$', '').str.replace(',', ''))
df2['production_budget'] = pd.to_numeric(df2['production_budget'].str.replace('$', '').str.replace(',', ''))
df2['domestic_gross'] = pd.to_numeric(df2['domestic_gross'].str.replace('$', '').str.replace(',', ''))

# df2['production_budget'] = pd.to_numeric(df2['production_budget'].str.replace('$', '')
# Calculate domestic ROI
df2['domestic_roi'] = ((df2['domestic_gross'] - df2['production_budget']) / df2['production_budget']) * 100

# Calculate worldwide ROI
df2['worldwide_roi'] = ((df2['worldwide_gross'] - df2['production_budget']) / df2['production_budget']) * 100

# Display the dataset with the calculated ROI
df2[['original_title', 'production_budget', 'worldwide_gross', 'worldwide_roi', 'domestic_roi']]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14264\1942295363.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['worldwide_gross'] = pd.to_numeric(df2['worldwide_gross'].str.replace('$', '').str.replace(',', ''))
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14264\1942295363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['worldwide_gross'] = pd.to_numeric(df2['worldwide_gross'].str.replace('$', '').str.replace(',', ''))
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14264\1942295363.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['production_budget'] = pd.to_numeric(df2['production_budget'].str.replace('$', '').str.replace(',', ''))
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14264\1942295363.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['production_budget'] = pd.to_numeric(df2['production_budget'].str.replace('$', '').str.replace(',', ''))
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14264\1942295363.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['domestic_gross'] = pd.to_numeric(df2['domestic_gross'].str.replace('$', '').str.replace(',', ''))
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14264\1942295363.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['domestic_gross'] = pd.to_numeric(df2['domestic_gross'].str.replace('$', '').str.replace(',', ''))
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14264\1942295363.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['domestic_roi'] = ((df2['domestic_gross'] - df2['production_budget']) / df2['production_budget']) * 100
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14264\1942295363.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['worldwide_roi'] = ((df2['worldwide_gross'] - df2['production_budget']) / df2['production_budget']) * 100
#                original_title  production_budget  worldwide_gross  \
# 0    How to Train Your Dragon          165000000        494870992
# 1                  Iron Man 2          170000000        621156389
# 2                   Toy Story           30000000        364545516
# 3                   Inception          160000000        835524642
# 4                      Avatar          425000000       2776345279
# ..                        ...                ...              ...
# 631   Insidious: The Last Key           10000000        167885588
# 632               Love, Simon           10000000         65520633
# 633             Truth or Dare            3500000         95127344
# 634                 12 Strong           35000000         71118378
# 635         A Wrinkle in Time          103000000        133401882
#
#      worldwide_roi  domestic_roi
# 0       199.921813     31.867413
# 1       265.386111     83.784312
# 2      1115.151720    539.320777
# 3       422.202901     82.860122
# 4       553.257713     78.942971
# ..             ...           ...
# 631    1578.855880    577.453300
# 632     555.206330    308.263410
# 633    2617.924114   1083.171857
# 634     103.195366     30.913466
# 635      29.516390     -2.447953
#
# [636 rows x 5 columns]

# %%
df2 #checking the data
# Out:
#                 genre_ids      id original_language            original_title  \
# 0     [14, 12, 16, 10751]   10191                en  How to Train Your Dragon
# 1           [12, 28, 878]   10138                en                Iron Man 2
# 2         [16, 35, 10751]     862                en                 Toy Story
# 3           [28, 878, 12]   27205                en                 Inception
# 4       [28, 12, 14, 878]   19995                en                    Avatar
# ..                    ...     ...               ...                       ...
# 631        [9648, 27, 53]  406563                en   Insidious: The Last Key
# 632       [35, 18, 10749]  449176                en               Love, Simon
# 633              [53, 27]  460019                en             Truth or Dare
# 634   [10752, 18, 36, 28]  429351                en                 12 Strong
# 635  [12, 878, 10751, 14]  407451                en         A Wrinkle in Time
#
#      popularity release_date                     title  vote_average  \
# 0        28.734   2010-03-26  How to Train Your Dragon           7.7
# 1        28.515   2010-05-07                Iron Man 2           6.8
# 2        28.005   1995-11-22                 Toy Story           7.9
# 3        27.920   2010-07-16                 Inception           8.3
# 4        26.526   2009-12-18                    Avatar           7.4
# ..          ...          ...                       ...           ...
# 631      16.017   2018-01-05   Insidious: The Last Key           6.1
# 632      15.608   2018-03-16               Love, Simon           8.2
# 633      14.354   2018-04-13             Truth or Dare           6.0
# 634      13.183   2018-01-19                 12 Strong           5.6
# 635      12.529   2018-03-09         A Wrinkle in Time           5.0
#
#      vote_count                     movie  production_budget  domestic_gross  \
# 0          7610  How to Train Your Dragon          165000000       217581232
# 1         12368                Iron Man 2          170000000       312433331
# 2         10174                 Toy Story           30000000       191796233
# 3         22186                 Inception          160000000       292576195
# 4         18676                    Avatar          425000000       760507625
# ..          ...                       ...                ...             ...
# 631        1306   Insidious: The Last Key           10000000        67745330
# 632        3165               Love, Simon           10000000        40826341
# 633        2005             Truth or Dare            3500000        41411015
# 634        1312                 12 Strong           35000000        45819713
# 635        1073         A Wrinkle in Time          103000000       100478608
#
#      worldwide_gross  domestic_roi  worldwide_roi
# 0          494870992     31.867413     199.921813
# 1          621156389     83.784312     265.386111
# 2          364545516    539.320777    1115.151720
# 3          835524642     82.860122     422.202901
# 4         2776345279     78.942971     553.257713
# ..               ...           ...            ...
# 631        167885588    577.453300    1578.855880
# 632         65520633    308.263410     555.206330
# 633         95127344   1083.171857    2617.924114
# 634         71118378     30.913466     103.195366
# 635        133401882     -2.447953      29.516390
#
# [636 rows x 15 columns]

# %%
# Sort the DataFrame based on the 'vote_average' column in ascending order
df2_sorted = df2.sort_values(by='vote_average')
df2=df2_sorted
df2
# Out:
#                genre_ids      id original_language  \
# 93                  [35]   71880                en
# 420                 [53]  241251                en
# 375        [28, 12, 878]  166424                en
# 233                 [35]   87818                en
# 15   [28, 12, 10751, 14]   10196                en
# ..                   ...     ...               ...
# 590             [18, 35]  490132                en
# 579         [12, 28, 14]  299536                en
# 3          [28, 878, 12]   27205                en
# 270          [18, 10402]  244786                en
# 131             [18, 80]     311                en
#
#                   original_title  popularity release_date  \
# 93                 Jack and Jill      11.277   2011-11-11
# 420            The Boy Next Door       7.062   2015-01-23
# 375               Fantastic Four      16.360   2015-08-07
# 233                     Movie 43      12.813   2013-01-25
# 15            The Last Airbender      16.595   2010-07-01
# ..                           ...         ...          ...
# 590                   Green Book      36.284   2018-11-16
# 579       Avengers: Infinity War      80.773   2018-04-27
# 3                      Inception      27.920   2010-07-16
# 270                     Whiplash      28.784   2014-10-10
# 131  Once Upon a Time in America      17.717   1984-06-01
#
#                            title  vote_average  vote_count  \
# 93                 Jack and Jill           4.1        1124
# 420            The Boy Next Door           4.4        1382
# 375               Fantastic Four           4.4        3837
# 233                     Movie 43           4.4        1332
# 15            The Last Airbender           4.6        2143
# ..                           ...           ...         ...
# 590                   Green Book           8.3        3499
# 579       Avengers: Infinity War           8.3       13948
# 3                      Inception           8.3       22186
# 270                     Whiplash           8.4        7908
# 131  Once Upon a Time in America           8.4        2243
#
#                            movie  production_budget  domestic_gross  \
# 93                 Jack and Jill           79000000        74158157
# 420            The Boy Next Door            4000000        36006065
# 375               Fantastic Four          120000000        56117548
# 233                     Movie 43           10000000         8840453
# 15            The Last Airbender          150000000       131772187
# ..                           ...                ...             ...
# 590                   Green Book           23000000        85080171
# 579       Avengers: Infinity War          300000000       678815482
# 3                      Inception          160000000       292576195
# 270                     Whiplash            3300000        13092006
# 131  Once Upon a Time in America           30000000         5321508
#
#      worldwide_gross  domestic_roi  worldwide_roi
# 93         150519217     -6.128915      90.530654
# 420         53401938    800.151625    1235.048450
# 375        167849187    -53.235377      39.874322
# 233         31164747    -11.595470     211.647470
# 15         319713881    -12.151875     113.142587
# ..               ...           ...            ...
# 590        322034439    269.913787    1300.149735
# 579       2048134200    126.271827     582.711400
# 3          835524642     82.860122     422.202901
# 270         38969037    296.727455    1080.879909
# 131          5575648    -82.261640     -81.414507
#
# [636 rows x 15 columns]

# %%
sort_popularity = df2.sort_values(by=['popularity'], ascending=True) #sorting the data by popularity
sort_popularity
# Out:
#              genre_ids      id original_language  \
# 259               [35]  116741                en
# 51   [28, 12, 27, 878]   35791                en
# 578      [28, 27, 878]  173897                en
# 183      [28, 27, 878]   71679                en
# 115      [28, 878, 12]   49538                en
# ..                 ...     ...               ...
# 262      [28, 878, 12]  118340                en
# 116      [878, 28, 12]   24428                en
# 261       [28, 12, 14]  122917                en
# 260           [28, 53]  245891                en
# 579       [12, 28, 14]  299536                en
#
#                                 original_title  popularity release_date  \
# 259                             The Internship       0.600   2013-06-07
# 51                    Resident Evil: Afterlife       0.667   2010-09-10
# 578           Resident Evil: The Final Chapter       0.844   2017-01-27
# 183                 Resident Evil: Retribution       1.325   2012-09-14
# 115                         X-Men: First Class       1.447   2011-06-03
# ..                                         ...         ...          ...
# 262                    Guardians of the Galaxy      49.606   2014-08-01
# 116                               The Avengers      50.289   2012-05-04
# 261  The Hobbit: The Battle of the Five Armies      53.783   2014-12-17
# 260                                  John Wick      78.123   2014-10-24
# 579                     Avengers: Infinity War      80.773   2018-04-27
#
#                                          title  vote_average  vote_count  \
# 259                             The Internship           6.2        2631
# 51                    Resident Evil: Afterlife           5.9        2119
# 578           Resident Evil: The Final Chapter           5.9        1859
# 183                 Resident Evil: Retribution           5.7        2321
# 115                         X-Men: First Class           7.2        8211
# ..                                         ...           ...         ...
# 262                    Guardians of the Galaxy           7.9       17958
# 116                               The Avengers           7.6       19673
# 261  The Hobbit: The Battle of the Five Armies           7.3        8392
# 260                                  John Wick           7.2       10081
# 579                     Avengers: Infinity War           8.3       13948
#
#                                          movie  production_budget  \
# 259                             The Internship           58000000
# 51                    Resident Evil: Afterlife           57500000
# 578           Resident Evil: The Final Chapter           40000000
# 183                 Resident Evil: Retribution           65000000
# 115                         X-Men: First Class          160000000
# ..                                         ...                ...
# 262                    Guardians of the Galaxy          170000000
# 116                               The Avengers          225000000
# 261  The Hobbit: The Battle of the Five Armies          250000000
# 260                                  John Wick           30000000
# 579                     Avengers: Infinity War          300000000
#
#      domestic_gross  worldwide_gross  domestic_roi  worldwide_roi
# 259        44672764         93672764    -22.977993      61.504766
# 51         60128566        295874190      4.571419     414.563809
# 578        26844692        314101190    -32.888270     685.252975
# 183        42345531        240647629    -34.853029     270.227122
# 115       146408305        355408305     -8.494809     122.130191
# ..              ...              ...           ...            ...
# 262       333172112        770867516     95.983595     353.451480
# 116       623279547       1517935897    177.013132     574.638176
# 261       255119788        945577621      2.047915     278.231048
# 260        43037835         76235001     43.459450     154.116670
# 579       678815482       2048134200    126.271827     582.711400
#
# [636 rows x 15 columns]

# %% [markdown]
# #  DATA VISUALIZATION

# %% [markdown]
# The graphical representation of the data. Scatter plots were used for this analysis.

# %% [markdown]
# # SCATTER PLOT

# %%
plt.figure(figsize=(10, 6))
plt.scatter(production_budget, worldwide_roi, marker='o')
plt.title('Production Budget vs. Worldwide ROI')
plt.xlabel('Production Budget')
plt.ylabel('Worldwide ROI')
plt.grid(True)
plt.show()

# %% [markdown]
# This scatter plot shows a positive correlation between the two variables, suggesting
# that films with higher production budgets tend to have higher worldwide ROI. However, there is also a lot of variation in
# the data, suggesting that other factors also influence worldwide ROI

# %%
# Extract the 'domestic_roi' and 'production_budget' columns
domestic_roi = df2['domestic_roi']
production_budget = df2['production_budget']

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(production_budget, domestic_roi, marker='o')
plt.title('Production Budget vs. Domestic ROI')
plt.xlabel('Production Budget')
plt.ylabel('Domestic ROI')
plt.grid(True)

# Show the scatter plot
plt.show()

# %%
vote_average = df2['vote_average']
vote_count = df2['vote_count']

# Create a scatter plot
plt.scatter(vote_average, vote_count, marker='o')

# Add labels and a title
plt.xlabel('Vote average')
plt.ylabel('Vote count')
plt.title('Vote Average vs. Vote Count')

# Show the plot
plt.show()

# %% [markdown]
# This scatter plot shows a positive correlation between the two variables, suggesting that films with higher vote averages tend to also have higher vote counts. However, there are some outliers, such as films that were less popular with the general public but were popular with a small group of critics.

# %%
domestic_gross = df2['domestic_gross']
worldwide_gross = df2['worldwide_gross']

# Create a scatter plot
plt.scatter(domestic_gross, worldwide_gross, marker='o')

# Add labels and a title
plt.xlabel('Domestic gross')
plt.ylabel('Worldwide gross')
plt.title('Domestic Gross vs. Worldwide Gross')

# Show the plot
plt.show()

# %% [markdown]
# This scatter plot shows a strong correlation between the two variables, suggesting that films with higher domestic gross tend to also have higher worldwide gross. However, there are some outliers, such as films that were more popular in international markets than in the domestic market.

# %%
# Extract the popularity and budget variables
popularity = df2['popularity']
budget = df2['production_budget']

# Create a scatter plot
plt.scatter(popularity, budget, marker='o')

# Add labels and a title
plt.xlabel('Popularity')
plt.ylabel('Budget')
plt.title('Popularity vs. Budget')

# Show the plot
plt.show()

# %% [markdown]
# The scatter plot shows that movies with a higher production budget are more popular
